# %%
from cspExamples import csp1, csp2, cspCoords, crossword1
from notebookCSPSetup import setup, reduceDomain, restoreDomains, highlightArc
from cspConsistency import Con_solver, Search_with_AC_from_CSP
from searchDepthFirst import Depth_first_search
from utilities import cspToJson
import utilities
def searchThreadFunction():
    searcher = Depth_first_search(Search_with_AC_from_CSP(csp2))
    print("Finished")
    return searcher

# %%
Con_solver.max_display_level = 3
Con_solver.max_step_level = 3
Con_solver.manual_step = True
Con_solver.auto_step_speed = 0.5

# %%
setup(cspToJson(csp2))
# Out:
# 	<div id="field_d3"/>
#     <div id="menu"/>

# %%
result = utilities.executeThread(searchThreadFunction)
# Out:
# Processing arc ( B , A ne B )
